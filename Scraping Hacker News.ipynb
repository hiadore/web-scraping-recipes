# %% [markdown]
# # Scraping Hacker News
#
# We’re going to scrape the https://news.ycombinator.com/news front page, using
# requests and Beautiful Soup. Take some time to explore the page if you haven’t heard
# about it already. Hacker News is a popular aggregator of news articles that “hackers”
# (computer scientists, entrepreneurs, data scientists) find interesting.
# We’ll store the scraped information in a simple Python list of dictionary objects for
# this example. The code to scrape this page looks as follows:

# %%
import re

from bs4 import BeautifulSoup
import requests

articles = []

url = 'https://news.ycombinator.com/news'

r = requests.get(url)
html_soup = BeautifulSoup(r.text, 'html.parser')

for item in html_soup.find_all('tr', class_='athing'):
    item_a = item.find('a', class_='storylink')
    item_link = item_a.get('href') if item_a else None
    item_title = item_a.get_text(strip=True) if item_a else None
    
    next_row = item.find_next_sibling('tr')
    item_score = next_row.find('span', class_='score')
    item_score = item_score.get_text(strip=True) if item_score else '0 points'
    item_user = next_row.find('a', class_='hnuser')
    item_user = item_user.get_text(strip=True) if item_user else 'unknown user'
    # We use regex here to find the correct element
    item_comments = next_row.find('a', string=re.compile('\d+\s+comments?'))
    item_comments = item_comments.get_text(strip=True).replace('\xa0', ' ') if item_comments else '0 comments'
    
    articles.append({
        'link': item_link,
        'title': item_title,
        'score': item_score,
        'user': item_user,
        'comments': item_comments
    })
    
for article in articles:
    print(article)
    print()
# Out:
# {'link': 'https://www.sandimetz.com/blog/2016/1/20/the-wrong-abstraction', 'title': 'The Wrong Abstraction (2016)', 'score': '357 points', 'user': 'LopRabbit', 'comments': '95 comments'}
#
# {'link': 'https://www.cadc.uscourts.gov/internet/opinions.nsf/533D47AF883C8194852582CD0052B8D4/$file/17-7035.pdf', 'title': 'Public.resource.org wins appeal on right to publish the law [pdf]', 'score': '89 points', 'user': 'DannyBee', 'comments': '15 comments'}
#
# {'link': 'http://www.hurstwic.org/history/articles/manufacturing/text/viking_woodworking_riving.htm', 'title': 'Riving, a Viking-age woodworking technique', 'score': '157 points', 'user': 'sea6ear', 'comments': '59 comments'}
#
# {'link': 'https://quariety.com/2018/07/20/peertube-the-decentralized-youtube-succeeds-in-crowdfunding/', 'title': 'PeerTube, the “Decentralized YouTube”, succeeds in crowdfunding', 'score': '404 points', 'user': 'Roccan', 'comments': '238 comments'}
#
# {'link': 'https://www.scottaaronson.com/papers/philos.pdf', 'title': 'Why Philosophers Should Care About Computational Complexity [pdf]', 'score': '56 points', 'user': 'alokrai', 'comments': '3 comments'}
#
# {'link': 'https://blog.apnic.net/2016/04/04/dns-zombies/', 'title': 'DNS Zombies (2016)', 'score': '13 points', 'user': 'mjlee', 'comments': '0 comments'}
#
# {'link': 'https://www.quantamagazine.org/the-octonion-math-that-could-underpin-physics-20180720', 'title': 'The Octonion Math That Could Underpin Physics', 'score': '263 points', 'user': 'jonbaer', 'comments': '147 comments'}
#
# {'link': 'https://kanbanmail.app/', 'title': 'Show HN: Kanban for E-Mail', 'score': '243 points', 'user': 'humbfool2', 'comments': '121 comments'}
#
# {'link': 'item?id=17580515', 'title': 'Amplemarket (YC W14) Seeks Software Engineer in Lisbon, Portugal', 'score': '0 points', 'user': 'unknown user', 'comments': '0 comments'}
#
# {'link': 'https://opnsec.com/2018/07/into-the-borg-ssrf-inside-google-production-network/', 'title': 'Into the Borg – SSRF inside Google production network', 'score': '178 points', 'user': 'red0point', 'comments': '32 comments'}
#
# {'link': 'https://www.brennancenter.org/publication/purges-growing-threat-right-vote', 'title': 'Purges: A Growing Threat to the Right to Vote', 'score': '23 points', 'user': 'cmurf', 'comments': '8 comments'}
#
# {'link': 'https://spectrum.ieee.org/view-from-the-valley/biomedical/diagnostics/new-wearable-sensor-detects-stress-hormone-in-sweat', 'title': 'New Wearable Sensor Detects Stress Hormone in Sweat', 'score': '68 points', 'user': '0xbxd', 'comments': '5 comments'}
#
# {'link': 'https://lithub.com/do-great-writers-really-steal-on-plagiarism-and-publishing/', 'title': 'Do Great Writers Really Steal?', 'score': '18 points', 'user': 'd99kris', 'comments': '5 comments'}
#
# {'link': 'http://www.bbc.com/travel/story/20180719-the-city-that-lit-the-world', 'title': 'New Bedford, Massachusetts: The city that once lit the world', 'score': '17 points', 'user': 'MiriamWeiner', 'comments': '1 comment'}
#
# {'link': 'https://multinational.io/', 'title': 'Show HN: Compare benefits of second passport based on the one you have', 'score': '106 points', 'user': 'askytb', 'comments': '71 comments'}
#
# {'link': 'https://spectrum.ieee.org/automaton/robotics/robotics-hardware/darpa-wants-your-insect-scale-robots-for-a-micro-olympics', 'title': 'A new Darpa program to develop insect-scale robots', 'score': '121 points', 'user': 'robg', 'comments': '37 comments'}
#
# {'link': 'https://www.bostonglobe.com/ideas/2018/07/13/why-history-always-about-humans/kXSi8rJLcfQKYR1P3EDUIM/story.html', 'title': 'Why is history always about humans?', 'score': '41 points', 'user': 'Petiver', 'comments': '37 comments'}
#
# {'link': 'https://www.nytimes.com/interactive/2018/07/18/upshot/nike-vaporfly-shoe-strava.html', 'title': 'Nike Says Its $250 Running Shoes Will Make You Run Much Faster', 'score': '180 points', 'user': 'sethbannon', 'comments': '215 comments'}
#
# {'link': 'https://www.cjr.org/business_of_news/tech-journalism.php', 'title': 'We need a new model for tech journalism', 'score': '85 points', 'user': 'apress', 'comments': '52 comments'}
#
# {'link': 'https://datatransferproject.dev/', 'title': 'The Data Transfer Project', 'score': '105 points', 'user': 'l2dy', 'comments': '46 comments'}
#
# {'link': 'https://www.indiehackers.com/round-table/what-tech-should-you-use-in-2018', 'title': 'What tech stacks are indie hackers using for their apps, and why?', 'score': '113 points', 'user': 'ChanningAllen', 'comments': '103 comments'}
#
# {'link': 'http://www.doxsey.net/blog/tacit-knowledge', 'title': 'Tacit Knowledge', 'score': '4 points', 'user': 'cdoxsey', 'comments': '0 comments'}
#
# {'link': 'http://www.columbia.edu/~fdc/postal/', 'title': "Frank's Compulsive Guide to Postal Addresses", 'score': '40 points', 'user': 'pera', 'comments': '9 comments'}
#
# {'link': 'https://code.fb.com/ai-research/facebook-ai-research-expands-with-new-academic-collaborations/', 'title': 'Facebook AI Research Expands with New Academic Collaborations', 'score': '102 points', 'user': 'TamoC', 'comments': '76 comments'}
#
# {'link': 'https://techcrunch.com/2018/07/20/waymos-autonomous-vehicles-are-driving-25000-miles-every-day/', 'title': 'Waymo’s autonomous vehicles are driving 25,000 miles every day', 'score': '123 points', 'user': 'sahin-boydas', 'comments': '136 comments'}
#
# {'link': 'http://growth.eladgil.com/book/chapter-5-organizational-structure-and-hypergrowth/you-cant-delegate-culture-an-interview-with-patrick-collison/', 'title': 'Interview with Patrick Collison', 'score': '61 points', 'user': 'arikr', 'comments': '17 comments'}
#
# {'link': 'https://github.com/Puchaczov/Musoq', 'title': 'Show HN: Musoq – Use SQL on various data sources', 'score': '46 points', 'user': 'Puchaczov', 'comments': '12 comments'}
#
# {'link': 'http://www.erica.biz/2018/cockroach/', 'title': 'Sounding the Alarm: Now Is the Time to Be a Cockroach', 'score': '145 points', 'user': 'mooreds', 'comments': '120 comments'}
#
# {'link': 'https://www.mercurynews.com/2018/07/17/pge-wildfire-state-bill-blasted-as-bailout-by-some-deemed-vital-by-others/', 'title': 'PG&E; wildfire state bill AB33 blasted as bailout by some, deemed vital by others', 'score': '3 points', 'user': 'masonic', 'comments': '4 comments'}
#
# {'link': 'https://twitter.com/AltUSPressSec/status/1019955719964160006', 'title': 'A used voting machine from the 2016 election', 'score': '176 points', 'user': 'jpindar', 'comments': '59 comments'}
